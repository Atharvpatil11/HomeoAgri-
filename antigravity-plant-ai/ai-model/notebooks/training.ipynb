# %% [markdown]
# # Plant Disease Detection Model Training
#
# This notebook contains the workflow for training the CNN model.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os

print(tf.__version__)
